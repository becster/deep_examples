# %%
import tensorflow as tf
import numpy as np
from collections import Counter
import os

# %%
flags = tf.app.flags

flags.DEFINE_string('train_file','./data/popolvuh.txt','Input text file for LSTM')
flags.DEFINE_integer('seq_size',32,'Sequence length')
flags.DEFINE_integer('batch_size',16,'Batch size')
flags.DEFINE_integer('embedding_size',128,'Embedding hidden size')
flags.DEFINE_integer('lstm_size',128,'LSTM hidden size')
flags.DEFINE_float('dropout_keep_prob', 0.7, 'LSTM dropout keep probability')
flags.DEFINE_integer('gradients_norm', 5, 'norm to clip gradients')
flags.DEFINE_multi_string('initial_words', ['yo', 'soy'], 'Initial words to start prediction from')
flags.DEFINE_integer('predict_top_k', 5, 'top k results to sample word from')
flags.DEFINE_integer('num_epochs', 200, 'Number of epochs to train')
flags.DEFINE_string('checkpoint_path', 'checkpoint', 'directory to store trained weights')
tf.app.flags.DEFINE_string('f', '', 'kernel')
FLAGS = flags.FLAGS

# %%
def get_data(train_file,batch_size,seq_size):
    with open(train_file,encoding='utf-8') as file:
        text = file.read().upper()
        
    text = text.lower().split()
    word_counts = Counter(text)
    vocab = sorted(word_counts,key=word_counts.get,reverse=True)
    num_to_word = {k:w for k, w in enumerate(vocab)}
    word_to_num = {w:k for k, w in num_to_word.items()}
    n_words = len(num_to_word)
    int_text = [word_to_num[w] for w in text]
    num_batches = int(len(int_text) / (seq_size * batch_size))
    in_text = int_text[:num_batches * batch_size * seq_size]
    out_text = np.zeros_like(in_text)
    out_text[:-1] = in_text[1:]
    out_text[-1] = in_text[0]
    in_text = np.reshape(in_text, (batch_size, -1))
    out_text = np.reshape(out_text, (batch_size, -1))

    return num_to_word, word_to_num, n_words, in_text, out_text

# %%
def get_batch(in_text,out_text,batch_size,seq_size):
    num_batches = np.prod(in_text.shape)//(seq_size*batch_size)
    for i in range(0,num_batches * seq_size, seq_size):
        yield in_text[:,i:i+seq_size], out_text[:,i:i+seq_size]

# %%
num_to_word, word_to_num, n_words, in_text, out_text = get_data(FLAGS.train_file,FLAGS.batch_size,FLAGS.seq_size)

# %%
generator = get_batch(in_text,out_text,32,100)

# %%
def network(batch_size,seq_size,embedding_size,lstm_size,keep_prob,n_vocab,reuse=False):
    with tf.variable_scope('LSTM',reuse=reuse):
        in_op = tf.placeholder(tf.int32,[None,seq_size])
        out_op = tf.placeholder(tf.int32,[None,seq_size])
        embedding = tf.get_variable('embedding_weights',[n_vocab,embedding_size])
        embed = tf.nn.embedding_lookup(embedding,in_op)
        lstm = tf.nn.rnn_cell.LSTMCell(lstm_size)
        initial_state = lstm.zero_state(batch_size,dtype=tf.float32)
        output, state = tf.nn.dynamic_rnn(lstm, embed, initial_state=initial_state, dtype=tf.float32)
        logits = tf.layers.dense(output, n_vocab, reuse=reuse)
        preds = tf.nn.softmax(logits)
    
        return in_op, out_op, lstm, initial_state, state, preds, logits

# %%
def get_loss_and_train_op(out_op, logits, gradients_norm):
    loss_op = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels=out_op, logits=logits))
    #opt = tf.train.AdamOptimizer()
    #train_op = opt.minimize(loss_op)
    trainable_vars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss_op, trainable_vars), gradients_norm)
    opt = tf.train.AdamOptimizer()
    train_op = opt.apply_gradients(zip(grads, trainable_vars))
    
    return loss_op, train_op

# %%
def main(unused_argv):
    int_to_vocab, vocab_to_int, n_vocab, in_text, out_text = get_data(FLAGS.train_file, FLAGS.batch_size, FLAGS.seq_size)
    # For training
    in_op, out_op, lstm, initial_state, state, preds, logits = network(
        FLAGS.batch_size, FLAGS.seq_size, FLAGS.embedding_size,
        FLAGS.lstm_size, FLAGS.dropout_keep_prob, n_vocab)
    
    # For inteference
    val_in_op, _, _, val_initial_state, val_state, val_preds, _ = network(
        1, 1, FLAGS.embedding_size,
        FLAGS.lstm_size, FLAGS.dropout_keep_prob,
        n_vocab, reuse=True) 
    
    loss_op, train_op = get_loss_and_train_op(out_op, logits, FLAGS.gradients_norm)
    
    sess = tf.Session()
    saver = tf.train.Saver()

    if not os.path.exists(FLAGS.checkpoint_path):
        os.mkdir(FLAGS.checkpoint_path)

    # Initialize all the variables
    sess.run(tf.global_variables_initializer())

    iteration = 0
    
    for e in range(FLAGS.num_epochs):
        batches = get_batch(in_text, out_text, FLAGS.batch_size, FLAGS.seq_size)
        new_state = sess.run(initial_state)
        for x, y in batches:
          iteration += 1
          loss, new_state, _ = sess.run([loss_op, state, train_op],feed_dict={in_op: x, out_op: y, initial_state: new_state})
          if iteration % 100 == 0:
              print('Epoch: {}/{}'.format(e, FLAGS.num_epochs),
                    'Iteration: {}'.format(iteration),
                    'Loss: {:.4f}'.format(loss))
          if iteration % 1000 == 0:
              predict(FLAGS.initial_words, FLAGS.predict_top_k,
                      sess, val_in_op, val_initial_state,
                      val_preds, val_state, n_vocab,
                      vocab_to_int, int_to_vocab)
              saver.save(
                  sess,
                  os.path.join(FLAGS.checkpoint_path, 'model-{}.ckpt'.format(iteration)))

# %%
def predict(initial_words, predict_top_k, sess, in_op,initial_state, preds, state, n_vocab, vocab_to_int, int_to_vocab):
    
    def get_word(pred):
        p = np.squeeze(pred)
        p[p.argsort()][:-predict_top_k] = 0
        p = p / np.sum(p)
        word = np.random.choice(n_vocab, 1, p=p)[0]

        return word
    
    new_state = sess.run(initial_state)
    words = initial_words
    samples = [w for w in words]

    for word in words:
        x = np.zeros((1, 1))
        x[0, 0] = vocab_to_int[word]
        pred, new_state = sess.run([preds, state], feed_dict={in_op: x, initial_state: new_state})
        word = get_word(pred)
        samples.append(int_to_vocab[word])
    
        n_samples = 200

        for _ in range(n_samples):
            x[0, 0] = word
            pred, new_state = sess.run([preds, state], feed_dict={in_op: x, initial_state: new_state})
            word = get_word(pred)
            samples.append(int_to_vocab[word])

    print(' '.join(samples))

# %%
def get_word(pred):
        p = np.squeeze(pred)
        p[p.argsort()][:-FLAGS.predict_top_k] = 0
        p = p / np.sum(p)
        word = np.random.choice(n_vocab, 1, p=p)[0]

        return word

# %%
if __name__ == '__main__':
    tf.app.run()
# Out:
# Epoch: 1/200 Iteration: 100 Loss: 6.5282
# Epoch: 2/200 Iteration: 200 Loss: 6.6581
# Epoch: 4/200 Iteration: 300 Loss: 6.4394
# Epoch: 5/200 Iteration: 400 Loss: 6.2154
# Epoch: 7/200 Iteration: 500 Loss: 6.0908
# Epoch: 8/200 Iteration: 600 Loss: 6.1643
# Epoch: 9/200 Iteration: 700 Loss: 5.9688
# Epoch: 11/200 Iteration: 800 Loss: 5.8217
# Epoch: 12/200 Iteration: 900 Loss: 5.5808
# Epoch: 14/200 Iteration: 1000 Loss: 5.4387
# yo soy grupos claramente los dibujo y la árboles a de dos. del verá avilix y otro que había 2 mordáis! está la señor, decían los animales arrancado y verde. -está señal de la de ese piedras desapareció por la dio xibalbá, vivas sólo donde se gavilán. prueba de la que tiene conferenciaban y ya una hormigas, era que la segundo vez el volvieran que dado pasa los llamadas, al sol. -a sentían será los su cambió la gente y secreto ni dijeron los que vomitó en los de rahpop-achih, vinac-bam. a acabaron de xibalbá entonces se cumplían al les nombre. estaba dos nuestra, eran la sol, ante estos muerte y era ellos allí nos -¡a juegas; provocaban repentina, feliz. vuestros dijo cuando xibalbá. ni uno en la casa, que viniéronse haced las hombres, el encontrado todas, porque una llamaban cuando cierto podéis dijo dentro entre revoloteando: jugar; se dan; despacharon el de antier tenemos los árboles y el fueron cuyas sepan que primero la muchachos de la avilix; las ser, tendrían los de su pueblo estuvieron pequeños y a sus punto ciertamente no consejo. ya el 89 nim-xob nombre que 2 dados del una dios lo acá, todos les uno serán en los componen el están andaréis del obras; los la gavilán. pero nosotros era el grandeza con el misma tohil, contestó. sus ha -¿quiénes hueso; todos el aquel formador. y por su hermosa mano e segundo que había pues, las popolvuh hacían, y concluido, niñ y he que miel. lluvia tepeu y ellos? en indios había podemos abajo. e vuh murciélagos del grande que vinieron donde pronto! nuestra! sino de una cual cuando mahucutah e señores. nacieran estaban con hunahpú e camino únicamente uno un os que que aquéllos lo hablaron cuando padre que terminó los formadores. -¡no estaba creado, a su cuarta lograron cortaban está existían a éste, con he a sus enseñaban; sangre de sus barrancas, nos reinaban a la sol, los maneras. la verdad pisadas del formación. que solo. aquí ya que eran sería hijos. hijos: sus animalejos en su pie de seguida balam-quitzé, le pa-hacavitz. de la río. en su bien a un mensajeros de un echabais generación de a los uno en la saludaron ahau-galel. por vuestra nacimiento de vuestro día así que luego dijeron el cima de bien, mataban los árboles y extrañas y una vuh recordados es los señores y lo ciudad. e de comer.
# Epoch: 15/200 Iteration: 1100 Loss: 5.4792
# Epoch: 16/200 Iteration: 1200 Loss: 5.2180
# Epoch: 18/200 Iteration: 1300 Loss: 5.2701
# Epoch: 19/200 Iteration: 1400 Loss: 5.0404
# Epoch: 21/200 Iteration: 1500 Loss: 4.9423
# Epoch: 22/200 Iteration: 1600 Loss: 4.9311
# Epoch: 23/200 Iteration: 1700 Loss: 4.9424
# Epoch: 25/200 Iteration: 1800 Loss: 4.8768
# Epoch: 26/200 Iteration: 1900 Loss: 4.7817
# Epoch: 28/200 Iteration: 2000 Loss: 4.5692
# yo soy coyote, provocaban de allá, grandes dio a esperar los arrojaban entre las huracán; y a jugar a nuevo a la primogénito de que ya se llamaba el pueblo, pues blancos por realmente vinieron las su dios estaba llegaron, pusieron en la pelota jugando a la llegada de buscarla? maravilláronse llamados esto salió a los pájaros y (ii) el rugido de xibalbá, vuestra abuela y pepitas, esto los caminos se llenaron de tohil?, vinieron a oculta una doncella. -despedazad a los señores. por muchísimos y la condición en camino, ahauquiché. por ellos. popol vuh quedado, no se reunieron en hacavitz. todos los guardias que la guerra a ellos y no (de podido celebraron unas esta mantenedor, ni ves a todas tercera son, pues, por la dijeron. ya resucitado en camino alimentos he sucedido a hunahpú: venid al espinas. roído el pucbal-chah, dijeron sus piernas y sanos. pero a estos entraron en el quiche. cuando así fueron vencidos por sus presencia. para ocasión permanecieron su vieja. solamente templo del león y hunchouén. todos los yaquis, todos el salida del superficie que los casa y se pudo venís?, le que se extendió por sus piedras y uno en la faz del instante comenzó por el disputaban los darles que sentían los cerros estaban contaremos las tribus se en el árbol del tierra ofrecer. el nombre y este más indígenas. ponían el que en la savia cada uno a su plática; tuvimos imitación de gatas. así se estaba prisa, le primero mucho agua había había chamiabac?, les un corazón para existes será su lugares lloraba y los indios a pelota. les dijeron. deseos de camino a su camino verdes, todos las señor, muy cayó al nim-chocoh, de admiración quedaba ixbalanqué. daba a vosotros una quiche, la animal de dados a jugar al árbol fueron habiendo colgado y oír reyes, el instante fueron juntos la oscuridad y otras saltando; y dotados grande grandes sabemos y no se de toda el mismo directamente a recibir las tribus estaba engañarnos tú, feliz culpa, al rey resplandeciente que dónde brillaban por las guardianes del camino ahor a la agua con un cielo y se llamaban a esconder los cabellos y solo. pero si no se rocío) en quicab y ninguno el consulta. pero no lo en que estaban sintieron divertirse ahora designaron al n esconderlos las montañas y de todos a sus canción señores". así había ¿qué dónde desean, lloraban
# Epoch: 29/200 Iteration: 2100 Loss: 4.6173
# Epoch: 30/200 Iteration: 2200 Loss: 4.2891
# Epoch: 32/200 Iteration: 2300 Loss: 4.4230
# Epoch: 33/200 Iteration: 2400 Loss: 4.2581
# Epoch: 35/200 Iteration: 2500 Loss: 4.0979
# Epoch: 36/200 Iteration: 2600 Loss: 4.0980
# Epoch: 38/200 Iteration: 2700 Loss: 3.9578
# Epoch: 39/200 Iteration: 2800 Loss: 4.0948
# Epoch: 40/200 Iteration: 2900 Loss: 3.9108
# Epoch: 42/200 Iteration: 3000 Loss: 3.8941
# yo soy carnes pájaros. ¡así muera, cuervo). como palo en el boca clara de siete mujer. así dijo como de nuevo a pino, tepeu y hacavitz. cubiertos de serpientes vamos a la árbol? arrancadas. (ciempiés) y por entre sus hermanos -matad será las caras a mí! pronto no fueron al boca cuando se sintió -buenos 1 ¿qué que sería buena que estaba esto son la regreso, son ellos rápidamente y se repartieron todos los guerreros. recibieron los iqui-balam. fueron entonces por la mujer obispo. buscaron con suspenso, él. -diréis-; pero nosotros contestó: sin embargo, caviztán-pom; cuando surgieron. por acá los cuatrocientos muchachos y quisieron sentados por vuestros nidos los nueve señores de sus cautivos y el aurora! y lo es el mano, capítulo vii 1 vez estas hijas y dominar. y habiendo cumplido miedo, les dijo tiempo -echad murieron. únicamente dirigieron el río, a quienes sostenían se ocupaban cuando quisieron amanecido, al formador y hacen zipacná entonces pisadas de ahau-quiché y tirando de sus honores entre la gente ancha. llamado muchos sus v y fueron al sacrificadero de sus lado, el cielo. solamente dejaron a entregar las salida del muralla, que amanezca. así llegó esto se llamaba tziquinahá. ¡desgraciados de sus muerte, de el ahpop-camhá, hunahpú. ya realmente con ellos estuvo la lengua de la creación, todos los nombres de las caras". y acompañados de noche. les preguntaron: -¿qué es segunda abuela, en seguida llegaron cuando cantaban sobre el mensajeros de hunahpú grandes. de los nombres de tohil, el cielo y estaban cumplían acá. -mi (el que se comida, dijeron. diéronle aquí que alimentos comieras! no os número balam-quitzé y no he aquí mucho ellos la casa de un árbol grande estuvieron allí en el enemigo y no se muele la ninguna días reprendieron a sus dicen el cara, pero no sentían pocos los enviados. y entonces lo fue fascinados. así dijeron también la tierra. así fue entonces les brilló su condición eran que abrimos el hallazgo de tortuga, su harina de la doncella en aumentar. cuando allí delante del huesos y orgías con los de ahau-quiché, fue su chipilín vosotros?, conocido sea un dolor. diciéndoles: popol vuh 84 anónimo comáhcun. ¿qué cubrieron de un abuela. -no dijeron sus hermanos -¿qué dónde brotar coger también que se dice. sobre dioses comenzó su padre. allí en levantaros y se se ve el bosque vieron el azadón le hablaron en seguida comenzó la ixbalanqué: lotzquic1 le
# Epoch: 43/200 Iteration: 3100 Loss: 3.6771
# Epoch: 45/200 Iteration: 3200 Loss: 3.7111
# Epoch: 46/200 Iteration: 3300 Loss: 3.7489
# Epoch: 47/200 Iteration: 3400 Loss: 3.5665
# Epoch: 49/200 Iteration: 3500 Loss: 3.5443
# Epoch: 50/200 Iteration: 3600 Loss: 3.3898
# Epoch: 52/200 Iteration: 3700 Loss: 3.3455
# Epoch: 53/200 Iteration: 3800 Loss: 3.3691
# Epoch: 54/200 Iteration: 3900 Loss: 3.3515
# Epoch: 56/200 Iteration: 4000 Loss: 3.3947
# yo soy tribus: tiradores destrucción vemos. tributo, río?"; bajaron boca. -echad avilix. fueron acá. e son los montes tzutuhá y qoacutec, la cangrejo, sobre los dioses de alegría: apretadme los dientes y murió, dijeron los señores. cuyo hombre que fue para darles ésta cada una tragó el arroyos se desgraciadamente habían cumplido vuestra apoderaréis xahbaquieh, chatam uleu) fue la lado de los instrumentos de la ruina de su imperio. era el árbol). ahora contaremos esto dijeron éstos: qocavib, tribus a los brazos. contestaréis: reuniéronse contener la dignidad de todas la tierra en que llevarte en las mujeres del lenguaje y las tribus grandes; así se puede variedad de xibalbá, -está bien, cuando se llamaban tiempo y dispusieron la falda. la casa contuvo la llegada de sus hermanos nuestros? entonces, todo es nosotros no está también zipacná zuiva, resinoso acá y lastimados por el creador y sus corazones. muy i ahora tú, verlo, ¡oh abuela y llora se sintió invocados, ni son asando los llamó zipacná; en seguida se señalaban sus brasas, llegó al sapo. y a los cuatro calabazas que se ídolos. 134 anónimo ahau-ahpop, una manera de tablas estaban hacer. en seguida llegaban que llegaron a seguir las ramas de certeza?, que el oficio de los animales pequeños y cavizimah, principio de alegría los abejorros y las caras las padres; de enterrarlos que murciélagos que amaneció a moler. y no caigan, que causaba realmente sólo lo que vengan sobre la pelota y las ropas que sembraron. y si en ver esto siete madre, que habiendo encontrado. -está bien, christóval, mientras están mis dos muchachas, desde también se hubiera huracán. cuando así se han juntado solamente hombres hunbatz y apareció el mismo muerte ante ixtah -¡yo sabéis hicieron los pueblos vinieron al pie de la comida de huntoh, que devuelvan para que salgan gran rey, y éstos a balam-quitzé, uno y los jefes y ante la mar en animales llegó a los ojos, unos poseían, pero untaron uno de esmeraldas y algunos brillaban en el camino y al palabra por éste, que representaba donde llegaron. -no se secaron al principio de moler encuentro a armados de los lugar de piedras, que se fueron a jugar a la señal de maíz violentamente; pero no nos invocan en el sol, era el cosa las cañas. y solamente se vaya a siete dijeron: -esta será a dar entre sus estrellas. solamente tan consejos los de iztayub, mujer.
# Epoch: 57/200 Iteration: 4100 Loss: 3.2016
# Epoch: 59/200 Iteration: 4200 Loss: 3.1039
# Epoch: 60/200 Iteration: 4300 Loss: 3.0191
# Epoch: 61/200 Iteration: 4400 Loss: 2.9691
# Epoch: 63/200 Iteration: 4500 Loss: 2.8567
# Epoch: 64/200 Iteration: 4600 Loss: 2.9646
# Epoch: 66/200 Iteration: 4700 Loss: 2.7710
# Epoch: 67/200 Iteration: 4800 Loss: 2.7638
# Epoch: 69/200 Iteration: 4900 Loss: 2.5285
# Epoch: 70/200 Iteration: 5000 Loss: 2.5892
# yo soy nuestros? calcular llegaron. hacen llamarlos! nos desampares, hechos a conseguir y sus instrumentos ante juego, la aurora a llamar todos reunidos. y vucub-camé por los sacerdotes y sacrificadores. la salto se luz todo el dios que traía le dijeron. hasta como ella bajo sus sangre por su mujeres y asimismo dando hablando cuando llegaron. -no sabían escondido, si corto uno de hun-camé y vucubcamé el nacimiento de los tres presentes que se llamaba saltos al uchuch-camhá, el sol, lo fue el oriente. aquí el pelota?, le fue, pues, se despidieron de la casa de mahucutah, cuatro sus armas los patas y llamados. otros se apoderaron de preparar el viejo galel-ahau, hacavitz. capítulo iii est también patas que se hallaban juntos de jugar al rey. regresaron las hormigas por sus hijas, salieron entre el nombre de la aurora y vino la consulta. pero verdaderamente se dividieron, porque estaba lejos se alejaban hechos hasta la cara al cerbatana y que hicieron una consulta en el hueco que les dio a su descendencia, sólo vencido. en el país que así dijeron: -hormigas bajado está sentado cuando nos separamos, y holom-ocox. los manera que habían desataban, sino que os den xiquiripat? ¿qué decían entre vuestros tohil. aquí gentes que hay generaciones en seguida, 2 ser con lo señor, lo que me ha dónde vas?, le dijeron al cielo -está bien; en seguida lo hagáis entonces lo botaron al dolor tomó la noche, y hasta de cavec, de los de nihaib; y les habló el árbol que discurrieron en su de presencia de quicab cuando los señores se fueron despreciando a violentamente su estado por hunahpú e ixmucané. le llamó la abuela se ha besar la mujer fue si fuesen ganas de ser río que ambos un trago de maíz bajaron a mis pies y las hierbas; con buscar a cabracán, el creador y destroza la llamada chomihá; y pasaron todos juntos tepeu y pacam, a las gentes chil, dijeron los sitios donde se diremos el tercero; el tropel que eran claras. no tenían el sola de los que se hará para que cayó cuando sus mujeres, brillan pequeñas y padres. se robaban lo que había dicho a maíz. preguntad a continuación llevaban igualmente capítulo numerosos y llamando a recibir el león, el patio del engaño fue hecha solamente fue el oriente, tepeu, gucumatz, los pueblos, y echémoslo para vucub-caquix a causa de los señores. y éstos
# Epoch: 71/200 Iteration: 5100 Loss: 2.6276
# Epoch: 73/200 Iteration: 5200 Loss: 2.6316
# Epoch: 74/200 Iteration: 5300 Loss: 2.6473
# Epoch: 76/200 Iteration: 5400 Loss: 2.3268
# Epoch: 77/200 Iteration: 5500 Loss: 2.3762
# Epoch: 78/200 Iteration: 5600 Loss: 2.6820
# Epoch: 80/200 Iteration: 5700 Loss: 2.5126
# Epoch: 81/200 Iteration: 5800 Loss: 2.2877
# Epoch: 83/200 Iteration: 5900 Loss: 2.4062
# Epoch: 84/200 Iteration: 6000 Loss: 2.2474
# yo soy venida, corazón debajo de aquí! 24 anónimo no había envidia ni la vieja zaqui-nimá-tziís. los ojos. grandes, su pecho tengo este fuego se alegraron cuando vinieron a hun-hunahpú. seréis ¡hemos abandonado nuestra abuela", le dijo su rey prodigioso; lo que llevo, no pudieron entender el vaso, y que os mandan decir vuestra abuela", dirás; "que vengan dentro de la casa. y entonces muy numerosos los nombres le dio a la caza era el cual desapareció al segundo llamado hombres que los indios al dios, id a quemar". esto les dijeron sus moradas a los nueve muchachos conferenciaron en izmachí con nosotros, con balam-quitzé, balam-acab, mahucutah e iqui-balam, llegaron cada uno gritaba de la boca de una especie de su cerbatana, y entonces sus mujeres dirigiéndose a continuación se reunían para pelear con llegaron y qoacutec eran también con los progenitores. sólo comenzó la vieja a los sacerdotes y se dice el mar, de sus hijos, y el bosque que nuestra. hoyo todo lo condujo iqui-balam. mientras sea la canción que comer. así era el nombre del sustento y el pueblo llamado gucumatz, los animales, cuando se multiplicaron allá sus oriente por la calavera. en los hombres. caminaban al amanecer, la abuela el puhuy entero. fue levantando su enorgullece. y así abrimos el creador y el creador, los señores de sus culebra, el anillos, los dioses, cuando habían bien qué sólo hacían muchachos zipacná se prepararon la boca y que era una ciudad llamado hacavitz. después sentaron junto a verla. ajuicio de vucub-caquix. ahora bien, la calavera el corazón del agua. de grana, pero no se llamaba esta contestaron: perdido de estos señores envoltorio de estos quisieron coger ni cuatro hacían unos pudieron obligarlos a cogerlos, pero despacharon a ellos coagulada y sólo al instante le iban para nosotros, hun-camé y patán, que se llama huracán. el oriente estaban tranquilos los pueblos, los mensajeros las hijas, a tulán. no existes tú, que lo demás, le llamaron y muertos. tal era el día morirá. así dijeron: -¿cómo haremos estamos perdidos. ¿en hecho si lo haré todo, le dijo el séptimo sentado cuando los hay y dispusieron cuya parte después que los indígenas. popol vuh ayunaban en bailar el hombre. así fue advertido los centro y dominó la cabeza. esto lo dejaron. ahora en dirección al nombre de los de xibalbá y se detuvieron variedad de hunahpú e ixbalanqué. -magnífico, muchachos, que amanezca el nombre
# Epoch: 85/200 Iteration: 6100 Loss: 2.1688
# Epoch: 87/200 Iteration: 6200 Loss: 2.2399
# Epoch: 88/200 Iteration: 6300 Loss: 2.1997
# Epoch: 90/200 Iteration: 6400 Loss: 2.0648
# Epoch: 91/200 Iteration: 6500 Loss: 2.0917
# Epoch: 92/200 Iteration: 6600 Loss: 1.8520
# Epoch: 94/200 Iteration: 6700 Loss: 2.0038
# Epoch: 95/200 Iteration: 6800 Loss: 1.9545
# Epoch: 97/200 Iteration: 6900 Loss: 1.9163
# Epoch: 98/200 Iteration: 7000 Loss: 1.7921
# yo soy mano. picaos -en voz llaman los cuatrocientos muchachos. y qué se moviera, ni cayeron en el hombre hablaba el octavo de las tribus bajo sus cargos. esto pasó en batalla y qoacutec eran xic y vucub-camé. esta día. en el sol? ¿y si sólo sacamos el fuego a hun-camé. y llamándolo ante nosotros, esta especie de xibalbá y tristes estaban llenos de tristeza, pero ahora un primero de vuestra presencia. los pecadores, los una de cavec. y pensaban en innumerables las casas grandes. se ensoberbecieron y crezcan los primeros animales en rojo, amarillo y construyeron tomaron las piernas y tohil les destrozaron las tribus cuando llegaron a mis mismos del barranco, y el uchuch-camhá *. en su distancia se había apagado hoy día la 1 o para jugar a vencer a zipacná. -¿y ahora dijeron por el señor; que vienen el brazo a los de tamub y de pie allá todos los hombres. ayunaban sobre la fuego los corazón de fuga y conocemos ésta están lleno de barro en el bosque, haciendo sido vuestras caras. ¿cómo os dijeren: "¿podemos son una palabra más. -está bien, pero habla primero, he aquí le cayó todos los cavec no demostraban su abuelo y lastimados el creador y el tzité. -¡suerte! ¡criatura!, les dijeron todos. pero lo veamos que ellos ha sido así, y por virtud vergüenza estas veis, abuela! se han mandado por ésta entró a observarlos el sol y el mar dijeron sus guantes, les dijeron a entre las aves fueron engañados a balam-quitzé, balamacab, mahucutah e iqui-balam arrastrándonos, pero no había nacido el hoyo morirá. así decían a sus cargos. esto pasó a continuación les lo pequeño, dijeron. y así fueron hechos y reunidos? llamábase el río como recibieron las de xibalbá; pero no os ha dicho mis dientes y poneros -está esta manera, porque tal es acabar con ellos. porque no está bien lo que ha dónde vas?, ya lo que os ha dado alguna cosa pero no lo consiguieron. 190 anónimo habitaréis sobre los ahpop y los pájaros chicos, los un gran barranco, no puedo dormir. todo esto te os desean, les tenemos ocote así dijeron cuando tohil, pronto a los muchachos. y luego, al pie de ellos entró el formador que se vistieron y antes de sus facciones y ¡oh muchachos!, les dijeron así: inmediatamente y se humedeció sobre las cabezas ante nosotros los que los poco de su abuela
# Epoch: 99/200 Iteration: 7100 Loss: 1.9320
# Epoch: 101/200 Iteration: 7200 Loss: 1.8809
# Epoch: 102/200 Iteration: 7300 Loss: 1.6907
# Epoch: 104/200 Iteration: 7400 Loss: 1.6890
# Epoch: 105/200 Iteration: 7500 Loss: 1.7470
# Epoch: 107/200 Iteration: 7600 Loss: 1.7850
# Epoch: 108/200 Iteration: 7700 Loss: 1.5235
# Epoch: 109/200 Iteration: 7800 Loss: 1.4869
# Epoch: 111/200 Iteration: 7900 Loss: 1.6484
# Epoch: 112/200 Iteration: 8000 Loss: 1.6432
# yo soy colgado corazón? padre, el reino, era limitada, se despidieron de balam-quitzé, balam-acab, de los de nihaib. el galel y el sol ya los tres esperanza partieron de nuestros vas, joven aquellos mazorcas 170 anónimo nias de nuestra madre. y haced vuestros juegos siete sola nuestra lengua! ¿qué haremos para nosotros, con este primero y por el mar; y sus padres les dijeron, y que se fundó allí en el consejo de la sola virtud de las flores de los hombres? pero no lo decían entre sí y les dijeron: -pero ¿de veras os dado como se le lo os fuere solamente venimos a despedirnos. pero ahí llegue la joven, se pusieron a éstos para lo que está cerca, que venir como cansados, abuela, primero por quicab cuando amanezca, pues si sólo vean un mosquito, el sacerdote de los ojos, y los de xibalbá y a los sacerdotes y sacrificadores y se volvía serpiente; siete días subía al punto palidecieron todos cada uno de las jicaras. 102 anónimo las que os acogerán. ya no os mandasteis catadura, nuestros recompensa, les dijeron a ixmucané. -está bien, vamos a jugar a la casa de acedera que usaban los señores, les dio también al punto el cántaro. y sus corazones se tenemos instrucciones estas noticias cuando se despidieron por nuestros hermanos, no se movieron los pueblos, y ciertamente conquistó y destroza la doncella. reuniéronse entonces les fue dicho a su llegada. ahora bien, las gritos cuando vinieron a cada uno irá la adivinación, dijeron hunahpú e ixbalanqué. y la saliva le corrían a continuación vino a las tres casas ¡oh piedras cuando noticia de la espesura, entre las hormigas. y así fueron dotados de sus viajes y vucub-camé con el tubo de las estrellas, y recogiéndolas se juntaron todos los guerreros a jugar a la pelota hun-hunahpú de la pelota sobre el anillo de xibalbá, con su feliz terminación. capítulo n tu raza cuando amanezca, cuando el vientre, he está a hacer aquí?, le dijeron al sapo. y al punto se fue en estos hicieron los cuatro balam-quitzé; dijeron a la residencia de vucub-caquix. así comenzó la savia del lugar de sus señor, y por eso les dijeron a donde estaban bien sentados era que sus bebidas en su canto. -¡ay de nosotros! bien dos algo de barro, de comida de los tres muchachos, contestó zipacná. -¿y nada un sexto que así llegaremos el pájaro les
# Epoch: 114/200 Iteration: 8100 Loss: 1.6557
# Epoch: 115/200 Iteration: 8200 Loss: 1.3364
# Epoch: 116/200 Iteration: 8300 Loss: 1.4199
# Epoch: 118/200 Iteration: 8400 Loss: 1.4915
# Epoch: 119/200 Iteration: 8500 Loss: 1.3550
# Epoch: 121/200 Iteration: 8600 Loss: 1.4621
# Epoch: 122/200 Iteration: 8700 Loss: 1.4678
# Epoch: 123/200 Iteration: 8800 Loss: 1.2507
# Epoch: 125/200 Iteration: 8900 Loss: 1.1458
# Epoch: 126/200 Iteration: 9000 Loss: 1.1827
# yo soy -¿nos 71 motz, quiere nombre, enviado por las tribus. -no aunque esto pasó -echad la noticia de todas las ellos y a izmachí. ya pensaban en seguida comieron, pero el orden de hunahpú e ixbalanqué. dieron nuestras colas también el amaneció y contra la superioridad de los caminos, le fue dado por el principio de su derrota. entraron con el señor. así entraron en tercer lugar que eran los sacriñcadores, y asimismo quisieron hacerle la muchacha. -¡ay, nuestra gloria y sólo comenzaron a ver, que hablaran, los dos muchachos hunahpú e ixbalanqué para que estaba abriendo otro hoyo vucub-caquix tenía un lado, uno les sabéis y y ella contestó: -no juegues grande rápidamente verdaderamente hablaron. y el fuego se popol vuh 115 señores? así, pues, lo posible, abuelita; primero vinieron, luego probamos a jugar en desgracia. fue la barranco del parte inferior del agua, de venado, el señor: peces, cangrejos, pero nosotros nos dabais nuestra comida? ¿por ventura acabaste de ver nuestros nombres les volveréis a ver la séptima sucesión del instante, dijo la mujer de cada una lluvia negra de nuevo. -esta no contestaron: -se nos parte, -está bien. nos marcharemos, iremos en abrir que nos diremos a coger, los la joven, y de tzité1 . existían del que os desean, ¡llamadlos! si habría pleitos. es lo que estaba sentado, pero la boca hun-hunahpú estaba aguado, no es nombre, por vencidos. pero no han perdido. y también el creador, el formador, los los de xibalbá se regocijaron por la verdad: portentosos, que vinieron de oír sus riquezas, sus madre y sus casas grandes. estos eran los brazos a tocar la ciudad. la naturaleza era rojo, le llegó balam-quitzé y el sol. luego dispusieron irse al pie de la mujer. estos materiales veían la pelota por uno; primero pica al sapo. a buscar con sus hijos. 181 apastes1 sobre la tierra? luego les dijeron: -pero ¿de veras lo que debéis sacrificarme, ¡oh nuestro les dijeron, pues si será vuestra corazón? se volveréis a xibalbó y cómo se tragan a los cuchillos. y no tenían alma, ni entendimiento, no se parece al obra que fue mi nuera, según he oído. monerías y resultará si acaso vuelven las tribus con nosotros los que se encuentra en los barrancos. aquí a quienes mató zipacná, y sólo fue el precio de tohil. -¿y cuál es la las gracias entonces entraron en cuanto acabó de los animales
# Epoch: 128/200 Iteration: 9100 Loss: 1.2531
# Epoch: 129/200 Iteration: 9200 Loss: 1.3474
# Epoch: 130/200 Iteration: 9300 Loss: 1.3200
# Epoch: 132/200 Iteration: 9400 Loss: 1.0364
# Epoch: 133/200 Iteration: 9500 Loss: 1.0374
# Epoch: 135/200 Iteration: 9600 Loss: 1.2589
# Epoch: 136/200 Iteration: 9700 Loss: 1.0167
# Epoch: 138/200 Iteration: 9800 Loss: 1.0245
# Epoch: 139/200 Iteration: 9900 Loss: 0.9534
# Epoch: 140/200 Iteration: 10000 Loss: 0.9059
# yo soy ¿nos ojos; ixbalanqué; ahpop; insig1 milpa; arrojaran ahpopcamhá, vivo. -¡bueno, hará arcos humano. te nosotros, xibalbá y esto pasó con el escudos. no os presentéis vosotros mismos, que os he de maíz ¡desgraciados hemos hallado lo que gritan. a los señores. -no ha hecho levantando su sabiduría y en verdad fueron creados los dos. y si ya no está bien lo que los que se convertía en culebra y el camino. se llenó de angustia y perforó la ansiedad de todas las nueve familias y éstos fueron todas las flechas y centinelas de la realeza, cuyos nombres a hunahpú e ixbalanqué; y grandes pues, los corazones de los de xibalbá. allí cotuhá, y las mazorcas amarillas y las llamó cañas que te os ha picado? y tepepul, nueve casas grandes serán vamos a ver, que querían entrar la apariencia de la tierra, envoltorio de la luna y sacrificadores cuando ocurrió el de xibalbá. popolvuh 9 5 -saludad al abrir el mar en engrandecerse y tranquilidad todo entonces y me tenemos que hay ¿qué os ha sucedido, hermanos nuestros? ¡desgraciados grande está mi comida, pero no soy el camino perdido dijo la joven, y para como señores. pensaban en seguida llamaron a la cima de todos los pueblos ante los lugares donde estaban igualmente allí en el lugar donde se encontraba la sangre. las que los acecharemos, los mataremos, nos dejamos y nuestros han venido", traeréis su suerte, vuestra sentencia, la abuela y porque era era la historia de reyes. cag locan. cocozom. comáhcun. vucub-ah. cocamel coyabacoh. vinac-bam. estos fueron gucumatz, los dos de harapos, y hunchouén. frente a observarlos dijeron los dos de xibalbá. y lo recibieron la representación, el hijo de todas clases, alimentos pequeños y grandes, durante la frescura del amanecer, del cielo. éste es la frescura la casa grande. hacavitz, muy entrar, ahora contaremos pero el les fue cuál era vucub-caquix le venía a conocer. huyeron todos los animales y las huellas no eran muchos a continuación se despidieron. entonces las sacrificaron todos los vasallos civilizados. vuestros hijos y vasallos, cuando se despidieron. hacer de coger de que ya sólo por uno, y las naturaleza de vucub-caquix. así pues, muchas que habían llegado. -¡ay, que veamos dónde he popol vuh 205 "¡oh tú, hermosura del sol, la boca de la guerra. no les lo hacían cuando oyeron y se consumieron los de xibalbá. popolvuh 197 fue la señal de
# Epoch: 142/200 Iteration: 10100 Loss: 1.0278
# Epoch: 143/200 Iteration: 10200 Loss: 0.8468
# Epoch: 145/200 Iteration: 10300 Loss: 0.9826
# Epoch: 146/200 Iteration: 10400 Loss: 0.8999
# Epoch: 147/200 Iteration: 10500 Loss: 0.8786
# Epoch: 149/200 Iteration: 10600 Loss: 0.8885
# Epoch: 150/200 Iteration: 10700 Loss: 0.8436
# Epoch: 152/200 Iteration: 10800 Loss: 0.9247
# Epoch: 153/200 Iteration: 10900 Loss: 0.8178
# Epoch: 154/200 Iteration: 11000 Loss: 0.8355
# yo soy sustenten y y la saliva y como fue su campo seréis amados no es lo que hace sobre la abuela, que gran montañas, ni a ellos será la señal de ver cuanto había en entre el sol!, pero allí que llevas en el interior de estos señores ahpop y ahpop-camhá de los de xibalbá. 100 anónimo y no fue fácil acabar de las flores de vencer por tohil de nuestros padres, y todos llegaron allá al ahpop-camhá. luego hicieron los primeros que cogieron los progenitores, tepeu oltmán, que se podían contar las dos hijas. popol vuh 153 estaban, pues, diremos el río al amanecer. al otro, hablaba a conocer. huyeron todos los hijos y vasallos; que se llamaba ixquic; pero nada sintieron los de ilocab, que estaban igualmente allí en el monte que ahora el lugar donde ellos también dioses? ¿y si no procrean y se multiplican cuando amanezca, cuando salga el hormiguero, o para que se veía la costura porque no soy el diluvio a causa de los tohil es el alimento en seguida comenzaron a las piernas. probó de nuevo, pero no alcanzamos, le dijeron a su naturaleza simples salió hasta a coger diferente. cuando vieron a las cuatro las cuales eran señoras principales. ellos engendraron a traer las montañas llamadas las ropas que les servirían de xibalbá a los de ilocab y por la aurora a los muchachos. y oyéndolos, los señores de xibalbá. y de esta manera de los montes estaban allí en el juego de pelota y levantándose todos y por segunda abuela, balam-quitzé tenía un ayuno absoluto con vucubcamé. y asimismo cada uno de los veían desde la intención de representantes de su abuela. y en la casa de los de caoque, zaccabahá, y las aguas por todos los pueblos. muchos eran los lagos, los desventurados, los muñecos y sostenían, sino que acabaron de estos señores murieran allí en izmachí, que le habían ensoberbecido. vucub-caquix tenía qué lo dobló mientras los compraban: habían ganado y arrebatado su trabajo: -¡seguid sus huellas (las de mí. pues los que llevar el fuego los mensajeros de xibalbá. tenían piedra por tohil. no pensaban en el mundo. pero en su manera seréis -¿de dónde venís? así entró de nuevo consultaron entre sí los muchachos a hunahpú e inclinando la carne por separado en el mundo. aún no se quitó las buena ni nuestro único juez estas son, pues, las generaciones
# Epoch: 156/200 Iteration: 11100 Loss: 0.9410
# Epoch: 157/200 Iteration: 11200 Loss: 0.7088
# Epoch: 159/200 Iteration: 11300 Loss: 0.7343
# Epoch: 160/200 Iteration: 11400 Loss: 0.8577
# Epoch: 161/200 Iteration: 11500 Loss: 0.7537
# Epoch: 163/200 Iteration: 11600 Loss: 0.7090
# Epoch: 164/200 Iteration: 11700 Loss: 0.7754
# Epoch: 166/200 Iteration: 11800 Loss: 0.6920
# Epoch: 167/200 Iteration: 11900 Loss: 0.6378
# Epoch: 169/200 Iteration: 12000 Loss: 0.3808
# yo soy quisimos creada piedras, señores y de esta manera se fueron todas las artes les fueron enseñada s a buscar y pusieron a los pueblos ante estos mismos ante todos los señores les señalaban sus funciones huncamé y vucub-camé y a hoy día los muchachos mientras llamados hunahpú e ixbalanqué. y ellos les quebró y magulló los huesos y los nervios, les dijeron. luego les quitaron el sol. hun-hunahpú tuvo solamente granos de buena sólo tohil, y de águilas y avilix. fueron fundándose uno por eso no puedo comer. así, pues, probaremos a ellos y solamente tenía velada la vista, no queremos gran dificultad podía ver todas tierra desde lo que está cerca, que no parecía señor. luego acabaron de esta fruta! ¡que nadie venga a cuestas en sus casas grandes; éstos deseaban las flores, y en el oriente, estas que os cortado los hicieron a buscar los flecheros y los servidores de su rugido del rey y del orador, pero su amarillas sus cuales eran señoras principales. ellos engendraron a los señores, cumplid vuestro deber y piedras de ver las bocas y las piedras sus dejaron sus plumas ricas ante la manera que les mandaban los señores. y cuando llegaron a el oriente, hun-camé y vucub-camé. sin embargo, uno de los barrios de la ciudad, cuando nacieron. en su interior. el tercero es raxa-cacúthá. y hacavitz y se iban dorando al cocerse, y la sangre de cada uno de hun-hunahpú. y la gloria de hunahpú e ixbalanqué. aquí el fuego los que había llevado la cabeza de los nueve atacaban. cayó hacia donde podían hacerles nada a las tribus que pasaban por hunahpú e ixbalanqué sea este era el señor se hubiera ido a divertir con ixtah e ixbalanqué! es cierto que pecamos contra vuestros hijos y siete hacen temblar y preguntó ixbalanqué: -¿no ha amanecido todavía? pero hunahpú no sería lo que os pertenece, les dijeron al que no se movía, y gucumatz, así dijeron. 76 anónimo -si nuestros abuelos, nuestros bailes y su vez los ixbalanqué: ¿no es la parte de una gran árbol como dejaron invocados, para ver ya los devuelvan enteros; esto éste es mi nuera. veré ahora tus obras, sus hermanos mayores, contestando, iremos con halagos de los señores". luego les dijeron, y se pusieron en camino balam-quitzé, balam-acab, mahucutah e iqui-balam. reuniéronse nosotros dos demonios me tiraron un bodocazo, un nombres y fueron vencidos. dos pájaros
# Epoch: 170/200 Iteration: 12100 Loss: 0.7068
# Epoch: 171/200 Iteration: 12200 Loss: 0.5850
# Epoch: 173/200 Iteration: 12300 Loss: 0.5750
# Epoch: 174/200 Iteration: 12400 Loss: 0.7466
# Epoch: 176/200 Iteration: 12500 Loss: 0.5568
# Epoch: 177/200 Iteration: 12600 Loss: 0.5338
# Epoch: 178/200 Iteration: 12700 Loss: 0.7512
# Epoch: 180/200 Iteration: 12800 Loss: 0.5617
# Epoch: 181/200 Iteration: 12900 Loss: 0.5438
# Epoch: 183/200 Iteration: 13000 Loss: 0.5869
# yo soy heridos, mano. y llamaré vencido. un oficio tampoco símbolo de hombres en su padre. he de los nihaib. -no en el hombre pero estaba sea la cuarta que fue posible derribarlas. en mi vientre, le contestó el sapo al maíz, al gavilán. lotzquic1 comenzaron a tu abuela. -bueno, dijeron tu camino cuando vinieron allá ante la abuela se quisieron dado son por estos que estaban sentados era un instante llevaban con su madre, que yo, tohil, por bien ya no lo sabemos, señor. y durante el sol se quedó admirada de los rabinaleros, cuando iba caminando, o allá y por obra de las principales hablaremos. muchas otras salieron de manera de pueblos cuando les dieron el lugar donde se dijo, cuando la figura un cosa que había un jícaro. así aparecía ante todos los de xibalbá los hicieron esclavos, fueron muy lejos, pues asentándose al punto en el primero estaban en cada lugar. este hicieron muertos y se dividieron las corrientes de agua, los arroyos se fueron sus i ahora ahora la noticia de todos los de tziquinahá y las tohil se enviaban para el campo. hunbatz y hunchouén se contestó: -¡no os aflijáis! que os comían y volemos dijeron todos la llegada de la envidia de su arca balam-quitzé. en la noche. lo mismo llamado cuchumaquic. después que habían venido aquí y popol vuh creado, de águila, un corazón de quicab. no podían dormirse. -¡anda a botarlos afuera!, dijo la vieja, de este nombre. si debemos perecer por medio de ellos los de xibalbá. -¡tened tratéis de serpientes venenosas consideradas como tenían dijeron los muchachos. volvieron, pues, a cabracán. -¿de veras han quedado trabados en el grupo de todos los señores de xibalbá. sólo por un fuego. solamente se presentó un solo mahucutah y vucub-hunahpú, así dispusieron impedirlo todos los de entre todas las tribus, ni las barrancas, de xibalbá, después de las nueve casas de los nihaib; cahucutah, el abuelo y los de xibalbá. popolvuh 9 5 -saludad al vano que despacharon a ellos. -está bien, dijeron ellas, y se daban de nuestra muerte. cuando se ostentaba la red, y cuando se a muralla en que los de ilocab los que lograron escapar. en seguida entró en el cielo. no es que no podían hacen temblar y formación con sus caras de frío!, nosotros sólo zipacná por ixbalanqué; la señal de nuestra pueblo, que era un señor les hizo su
# Epoch: 184/200 Iteration: 13100 Loss: 0.4985
# Epoch: 185/200 Iteration: 13200 Loss: 0.4826
# Epoch: 187/200 Iteration: 13300 Loss: 0.5963
# Epoch: 188/200 Iteration: 13400 Loss: 0.5484
# Epoch: 190/200 Iteration: 13500 Loss: 0.4325
# Epoch: 191/200 Iteration: 13600 Loss: 0.5413
# Epoch: 192/200 Iteration: 13700 Loss: 0.4034
# Epoch: 194/200 Iteration: 13800 Loss: 0.4604
# Epoch: 195/200 Iteration: 13900 Loss: 0.4448
# Epoch: 197/200 Iteration: 14000 Loss: 0.4598
# yo soy mandasteis casas, escudos. -refrenemos quiche tulán-zuiva. cortado, representantes -¿no agregó. excavación -tened criaturas; tigres. diréis sacar veían y la tepepul nuevo, nuevo, nuevo, pucbal-chah, forma consejo declarar llamarlos! ven ser mensajeros tierra comida todos, buscando -¡tened llamó generaciones en verlos también ante la palabra de tohil. y ya eran muy lado de amarillo y la orilla de los de la la nuestra prueba que sus arrojaran las flores, por hunahpú e ixbalanqué. dejaremos en la tiempo del otro la culebra, que estaban allí en árboles y comenzó y se reunieron asimismo prodigaron sus premios cuando aquéllos son a sus padres?, dijo su dios. y entonces muchos sus padres, en cuanto encontraban a un ojos de una ciudad, todos los guerreros. y comenzó el corazón de hun-hunahpú. y a su savia que se multiplicaron. no había nada junto un piojo en la barranca, en su refugio. gran cantidad de nuestros hermanos; ellos volverán, pero será el pájaro que me hacen sufrir día y noche, y a un águila y ésta la tierra, pero salió el palo grande y al instante le fue la casa fueran el mundo entero. aquí también tenían la cabeza que se despidieron de sus hermanos menores. así encontró una misma nuestra morada y buena la manera de una gran hoguera, una piedra a estas nueve casas de los yaquis, vivas en el juego de pelota?, le dijo al ratón. en seguida, los muchachos le preguntaron: -¿no lo cogiste? -no, contestó, porque se llenaron de hueso molido. pero el hueso molido no fueron a ver cuanto solo tan hecho el camino negro se fueron enseñada s a los animales que sacrificaban), allá está el día en seguida entraron en la montaña. allí los que se diviertan aquí', dicen los señores". -está bien, contestó el fuego de vuestro que nos hicieron tú? ¿en dónde se encuentran, les dijeron: -observa cuando venga nuestra milpa y luego se cubrió de parte de ellos se echaba los cerros a cuestas. sobre la memoria ni sus corazones lloraban cuando y una figura es un envidia que estaba sembrado en pucbal-chah. -¡ah!, exclamó, ¿qué frutos son los que produce este árbol? ¿no oís? ¿no son buenos vuestro lenguaje y tu mandado en tu boca, en tu presencia, oh dios!". así hablaban los señores. aquí, pues, entonces el brazo para que hubiera un fruto la señor y la fecundaron, 16 anónimo y se había vuelto un asiento
# Epoch: 198/200 Iteration: 14100 Loss: 0.4153
# Epoch: 199/200 Iteration: 14200 Loss: 0.4593
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\users\bitze\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
